# %%
FSPATH = "data/External_Data.xls"

# %%
import pandas
commodity_data = pandas.read_excel(FSPATH);

# %%
commodity_data = commodity_data.drop(commodity_data.index[2:243], axis=0)

# %%
commodity_data
# Out:
#                  Data Type                                              Index  \
# 0                Commodity                                            PALLFNF
# 1    Commodity.Description  All Commodity Price Index, 2005 = 100, include...
# 243                 2000M1                                           59.46435
# 244                 2000M2                                           61.75714
# 245                 2000M3                                           62.20454
# 246                 2000M4                                           58.33931
# 247                 2000M5                                           62.48459
# 248                 2000M6                                           64.61294
# 249                 2000M7                                           63.04158
# 250                 2000M8                                           63.94936
# 251                 2000M9                                           67.21111
# ...

# %%
commodity_data.to_csv("data//commodities_filtered.csv", index=False)
